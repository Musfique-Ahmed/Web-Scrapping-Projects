# %%
import pandas as pd

# %%
data = pd.read_csv("movies.csv")
data
# Out:
#      Unnamed: 0                                              Title Subtitle  \
# 0             0  Oh My Ghost! The Fierce Escape from Covid-19 (...      RAW
# 1             1                                    Bear Man (2023)      SUB
# 2             2     Kamen Rider 555 20th: Paradise Regained (2024)      SUB
# 3             3                                   Following (2024)      RAW
# 4             4                      Yumi's Cells the Movie (2024)      SUB
# ..          ...                                                ...      ...
# 715         715                                 Kill Me Now (2022)      RAW
# 716         716    Confidential Assignment 2: International (2022)      SUB
# 717         717                                        Leio (2022)      SUB
# 718         718                                    FOX LOVE (2022)      SUB
# 719         719                               The Mad Sword (2021)      SUB
#
#             Realise Time
# 0    2024-07-10 07:09:38
# ...

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)
data
# Out:
#                                                  Title Subtitle  \
# 0    Oh My Ghost! The Fierce Escape from Covid-19 (...      RAW
# 1                                      Bear Man (2023)      SUB
# 2       Kamen Rider 555 20th: Paradise Regained (2024)      SUB
# 3                                     Following (2024)      RAW
# 4                        Yumi's Cells the Movie (2024)      SUB
# ..                                                 ...      ...
# 715                                 Kill Me Now (2022)      RAW
# 716    Confidential Assignment 2: International (2022)      SUB
# 717                                        Leio (2022)      SUB
# 718                                    FOX LOVE (2022)      SUB
# 719                               The Mad Sword (2021)      SUB
#
#             Realise Time
# 0    2024-07-10 07:09:38
# 1    2024-07-10 06:53:47
# 2    2024-07-09 21:29:43
# 3    2024-07-08 15:17:59
# 4    2024-07-07 23:26:59
# ..                   ...
# ...
