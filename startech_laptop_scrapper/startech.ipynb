# %%
import pandas as pd

# %%
# df = pd.read_csv("D:\Python Study\FDS\Web Scrapping\Phone Price\laptop_data.csv")
df = pd.read_csv("C:\Musfique's Folder\Python\FDS\Web Scrapping\Phone Price\laptop_data.csv")
df.head(10)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_18880\3195566997.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\Musfique's Folder\Python\FDS\Web Scrapping\Phone Price\laptop_data.csv")
#                                                Model  Price Processor Brand  \
# 0  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 14" FHD Lap...  60500             AMD
# 1  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 14" FHD Lap...  60000             AMD
# 2  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 15.6" FHD L...  61000             AMD
# 3  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 14" FHD Lap...  63000             AMD
# 4  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 14" FHD Lap...  63000             AMD
# 5  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 15.6" FHD L...  63500             AMD
# 6  Lenovo IdeaPad 1 AMD Ryzen 5 7520U 15.6" FHD L...  63500             AMD
# ...

# %%
df.shape
# Out:
# (136, 66)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 66 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Model                          136 non-null    object
#  1   Price                          114 non-null    float64
#  2   Processor Brand                136 non-null    object
#  3   Processor Model                136 non-null    object
#  4   Processor Frequency            135 non-null    object
#  5   Processor Core                 136 non-null    object
#  6   Processor Thread               136 non-null    object
#  7   CPU Cache                      132 non-null    object
#  8   Display Size                   136 non-null    object
#  9   Display Type                   122 non-null    object
#  10  Display Resolution             136 non-null    object
#  11  Touch Screen                   60 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['Model', 'Price', 'Processor Brand', 'Processor Model',
#        'Processor Frequency', 'Processor Core', 'Processor Thread',
#        'CPU Cache', 'Display Size', 'Display Type', 'Display Resolution',
#        'Touch Screen', 'Display Features', 'RAM', 'RAM Type', 'Removable',
#        'Bus Speed', 'Total RAM Slot', 'Storage Type', 'Storage Capacity',
#        'Extra M.2 Slot', 'Supported SSD Type', 'Storage Upgrade',
#        'Graphics Model', 'Graphics Memory', 'Keyboard Type', 'TouchPad',
#        'WebCam', 'Speaker', 'Microphone', 'Optical Drive', 'Card Reader',
#        'HDMI Port', 'USB 2 Port', 'USB 3 Port',
#        'USB Type-C / Thunderbolt Port', 'Headphone & Microphone Port', 'WiFi',
#        'Bluetooth', 'Fingerprint Sensor', 'Operating System', 'Battery Type',
#        'Battery Capacity', 'Adapter Type', 'Color', 'Dimensions', 'Weight',
#        'Warranty Details', 'Chipset Model', 'Graphics Type', 'Audio Features',
# ...

# %%
hi = df[df['RAM'] == '8GB']
hi['RAM']
# Out:
# 10     8GB
# 14     8GB
# 19     8GB
# 24     8GB
# 26     8GB
# 27     8GB
# 28     8GB
# 32     8GB
# 40     8GB
# 47     8GB
# 56     8GB
# 69     8GB
# 131    8GB
# Name: RAM, dtype: object

# %% [markdown]
# Filtering products by pricing

# %%
type(df['Price'][0])
# Out:
# str

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')#errors='coerce' makes the other data such as string or other type to NaN
# df['Price'] = df['Price'].astype(int)
type(df['Price'][0])
# df['Price']
# Out:
# numpy.float64

# %%
invalid_price = df[df['Price'].isna()]
invalid_price
# Out:
#                                                  Model  Price Processor Brand  \
# 113  Lenovo IdeaPad Slim 3 15IRH8 Core i5 13th Gen ...    NaN           Intel
# 114  Lenovo IdeaPad Slim 3i 15ITL6 Core i3 11th Gen...    NaN           Intel
# 115  Lenovo V15 Gen 3 Core i3 12th Gen 15.6" FHD La...    NaN           Intel
# 116  Lenovo IdeaPad Slim 3 Ryzen 5 7520U 15.6" FHD ...    NaN             AMD
# 117  Lenovo IdeaPad Slim 3 15AMN8 Ryzen 5 7520U 15....    NaN             AMD
# 118  Lenovo IdeaPad Slim 3 Ryzen 5 7520U 15.6" FHD ...    NaN             AMD
# 119  Lenovo IdeaPad Slim 3 Ryzen 5 7520U 14" FHD La...    NaN             AMD
# 120  Lenovo IdeaPad Slim 3 Ryzen 5 7520U 14" FHD La...    NaN             AMD
# 121  Lenovo IdeaPad 3 15ALC6 AMD Ryzen 7 5700U 15.6...    NaN             AMD
# 122  Lenovo IdeaPad Slim 3 15ABR8 Ryzen 7 7730U 15....    NaN             AMD
# 123  Lenovo IdeaPad Slim 3 14ABR8 Ryzen 7 7730U Aby...    NaN             AMD
# ...

# %%
hi = df.isnull().sum()
type(hi)
# Out:
# pandas.core.series.Series

# %%
df.duplicated().sum()
# Out:
# 0
